# %% [markdown]
# <a href="https://colab.research.google.com/github/rudraaa11/Image-Recognition-Using-Yolo/blob/main/Image_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Feb 20 12:36:04 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.3/915.3 kB 41.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !unzip /content/data.zip
# Out:
# Archive:  /content/data.zip
#    creating: data/
#   inflating: data/classes.txt
#    creating: data/images/
#    creating: data/images/train/
#   inflating: data/images/train/093c4435-F650F0CF-D813-4866-918C-9D94D360AAB6.jpg
#   inflating: data/images/train/1094426c-FAA99666-63BF-418E-B9A5-66CDCC976CE7.jpg
#   inflating: data/images/train/14bb699e-E7713BF1-E459-4934-B8FF-0AE8866AC68B.jpg
#   inflating: data/images/train/24a185a8-FDC9DFC5-E1A4-4CC6-B514-97490D150EB5.jpg
#   inflating: data/images/train/2b168f4e-F00E04A6-CF55-4E39-99D9-5C0934ADFDFB.jpg
#   inflating: data/images/train/38e19903-F15E85E3-8ECF-430E-A31F-C3EFB4D57751.jpg
#   inflating: data/images/train/3b5900fa-D193A903-AE1A-4EDF-85A2-4DB15CF0BE91.jpg
#   inflating: data/images/train/40118577-DD56E7CE-DB68-4599-B71E-FA18FCC1AD86.jpg
#   inflating: data/images/train/5b5a85a7-FB1C5ACD-59C0-43FC-9D91-7616C8EFA565.jpg
#   inflating: data/images/train/68a4316d-E857DADA-9013-4DDF-9684-15E2DA873B8B.jpg
# ...

# %%
import yaml
import os

def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

  # Read class.txt to get class names
  if not os.path.exists(path_to_classes_txt):
    print(f'classes.txt file not found! Please create a classes.txt labelmap and move it to {path_to_classes_txt}')
    return
  with open(path_to_classes_txt, 'r') as f:
    classes = []
    for line in f.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  number_of_classes = len(classes)

  # Create data dictionary
  data = {
      'path': '/content/data',
      'train': 'images/train',
      'val': 'images/val',
      'nc': number_of_classes,
      'names': classes
  }

  # Write data to YAML file
  with open(path_to_data_yaml, 'w') as f:
    yaml.dump(data, f, sort_keys=False)
  print(f'Created config file at {path_to_data_yaml}')

  return

# Define path to classes.txt and run function
path_to_classes_txt = '/content/data/classes.txt'
path_to_data_yaml = '/content/data.yaml'

create_data_yaml(path_to_classes_txt, path_to_data_yaml)

print('\nFile contents:\n')
# !cat /content/data.yaml
# Out:
# Created config file at /content/data.yaml
#
# File contents:
#
# path: /content/data
# train: images/train
# val: images/val
# nc: 2
# names:
# - budweiser
# - promos

# %%
# !yolo detect train data=/content/data.yaml model=yolo11s.pt epochs=40 imgsz=640
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import yolo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-dcc9db5766aa> in <cell line: 0>()
# ----> 1 from ultralytics import yolo
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.4/112.6 GB disk)

# %%
# !yolo detect train data=/content/data.yaml model=yolov10s.pt epochs=60 imgsz=640
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train7/weights/best.pt source=/content/data/images/val save=True
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10l summary (fused): 197 layers, 25,720,994 parameters, 0 gradients, 126.3 GFLOPs
#
# image 1/9 /content/data/images/val/c502cd5d-EE19282F-CB30-4A8C-8BA4-4E02DEEBE4A6.jpg: 640x480 10 budweisers, 5 promoss, 60.2ms
# image 2/9 /content/data/images/val/cbf82d57-D2E42A36-E232-47CF-B7D9-084116696967.jpg: 640x480 12 budweisers, 2 promoss, 42.9ms
# image 3/9 /content/data/images/val/d3e9bf79-F29B706E-DA8F-4276-B08C-9CEFE5688975.jpg: 480x640 3 budweisers, 2 promoss, 47.6ms
# image 4/9 /content/data/images/val/d4b53bd3-C4966AD5-EA03-4697-A07D-7496663346AD.jpg: 640x480 10 budweisers, 3 promoss, 39.7ms
# image 5/9 /content/data/images/val/d5c21f4e-D8A69683-DE34-4BEC-A2F0-99D3B8BB761F.jpg: 640x480 8 budweisers, 2 prices, 36.9ms
# image 6/9 /content/data/images/val/df8d326a-EB1D4109-267E-4A4F-B18F-5182593C4C0E.jpg: 640x480 7 budweisers, 3 promoss, 36.9ms
# ...
